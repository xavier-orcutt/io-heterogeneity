# %% [markdown]
# # Calculating RMST Pseudo-Observations
#
# **This notebook calculates RMST pseudo-observations at 1 and 2 years for advanced non-small cell lung cancer patients with high PDL1 receiving pembrolizumab or pembrolizumab.**

# %%
import sys
sys.path.append('../..')

import pandas as pd

from utils.pseudo_obs import pseudo_observations_rmst

# %%
df = pd.read_csv('../outputs/pembro_chemo_features_df.csv')

# %%
df = df.set_index('PatientID')

# %%
df.shape
# Out:
# (1803, 163)

# %%
treatment_df = pd.read_csv('../outputs/pembro_chemo_index.csv')

# %%
treatment_df.shape
# Out:
# (34491, 3)

# %%
df = pd.merge(df, treatment_df, on = 'PatientID', how = 'left')

# %%
df.shape
# Out:
# (1803, 166)

# %%
df['StartDate'] = pd.to_datetime(df['StartDate'])

# %%
df['treatment_year'] = df['StartDate'].dt.year

# %%
df = df.query('treatment_year <= 2023')

# %%
pseudo_rmst = pseudo_observations_rmst(
    df['duration'].values,
    df['event'].values,
    tau = 365
)

df['rmst_pseudo_1y'] = pseudo_rmst

# %%
pseudo_rmst = pseudo_observations_rmst(
    df['duration'].values,
    df['event'].values,
    tau = 730
)

df['rmst_pseudo_2y'] = pseudo_rmst

# %%
df = df.reset_index()

# %%
df = df[['PatientID', 'rmst_pseudo_1y', 'rmst_pseudo_2y']]

# %%
df.head(5)
# Out:
#        PatientID  rmst_pseudo_1y  rmst_pseudo_2y
# 0  FF032CFC52D8D      367.670699      741.872867
# 1  F12CC5261C079      367.670699      741.872867
# 2  FD0C44C783F30       22.658240       20.960921
# 3  FE724F9396C8C      159.895247      152.236426
# 4  F282B4DDD99E7      125.024641      117.852264

# %%
df.to_csv('../outputs/pseudo_obs_rmst.csv', index = False)
