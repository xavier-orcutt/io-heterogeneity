# %% [markdown]
# # Calculating RMST Pseudo-Observations
#
# **This notebook calculates RMST pseudo-observations at 1 and 2 years for MSI-H metastatic colorectal cancer patients receiving pembrolizumab or chemotherapy.**

# %%
import sys
sys.path.append('../..')

import pandas as pd

from utils.pseudo_obs import pseudo_observations_rmst

# %%
df = pd.read_csv('../outputs/pembro_chemo_features_df.csv')

# %%
df = df.set_index('PatientID')

# %%
df.shape
# Out:
# (1208, 169)

# %%
df = df.query('met_diagnosis_year <= 2023')

# %%
pseudo_rmst = pseudo_observations_rmst(
    df['duration'].values,
    df['event'].values,
    tau = 365
)

df['rmst_pseudo_1y'] = pseudo_rmst

# %%
pseudo_rmst = pseudo_observations_rmst(
    df['duration'].values,
    df['event'].values,
    tau = 730
)

df['rmst_pseudo_2y'] = pseudo_rmst

# %%
df = df.reset_index()

# %%
df = df[['PatientID', 'rmst_pseudo_1y', 'rmst_pseudo_2y']]

# %%
df.head(5)
# Out:
#        PatientID  rmst_pseudo_1y  rmst_pseudo_2y
# 0  F12B04C749133      366.950404      740.005907
# 1  FFFB7D51F655C      366.950404      739.813368
# 2  F6E393E2A3FBA      366.950404      740.005907
# 3  F2CC00A95DC86      366.950404      740.005907
# 4  F4C4B85E9B006      366.950404      740.005907

# %%
df.to_csv('../outputs/pseudo_obs_rmst.csv', index = False)
